# %%
# !pip install /lakehouse/default/Files/lucidsparkutils-1.0.1-py3-none-any.whl --q

# %%
import lucid_spark_utils as lucid
utils = lucid.LucidUtils()
# Out:
# StatementMeta(, a2072f2e-2676-43dd-b459-183700f0cc6c, 5, Finished, Available)

# %%
# Load sample df
df = spark.sql('select * from bronze.customers')

# df.show(5)
# Out:
# StatementMeta(, a2072f2e-2676-43dd-b459-183700f0cc6c, 6, Finished, Available)

# %%
###### Doesn't work with .whl installation to envt ######

# Set vars
storage_container_endpoint = 'my_storage_endpoint'
file_format = 'csv'
file_name = 'customers_pandas_test1'

# Write file
utils.write_file(df, file_name, storage_container_endpoint, file_format)
# Out:
# StatementMeta(, a2072f2e-2676-43dd-b459-183700f0cc6c, 7, Finished, Available)
# An error occurred in write_file_to_storage: Cannot save file into a non-existent directory: 'my_storage_endpoint/Files'
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 9
#       6 file_name = 'customers_pandas_test1'
#       8 # Write file
# ----> 9 utils.write_file(df, file_name, storage_container_endpoint, file_format)
#
# File ~/cluster-env/clonedenv/lib/python3.10/site-packages/lucid_spark_utils/utils.py:212, in LucidUtils.write_file(self, dataframe, file_name, storage_container_endpoint, file_format)
#     182 """
#     183 Writes a DataFrame to a file in the storage account.
#     184
#    (...)
#     209     write_file(dataframe, file_name, storage_container_endpoint, file_format)
#     210 """
#     211 self.logger.info(f"Writing file")
# ...
